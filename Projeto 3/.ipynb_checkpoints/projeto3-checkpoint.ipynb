# %% [markdown]
# ## Projeto 3

# %% [markdown]
# ## Taxa de desemprego

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\João Rodrigues\Documents\Ciencia dos Dados\CD\Projeto 3

# %%
td = pd.read_excel("indicator_t 15-24 unemploy.xlsx.")
td
# Out:
#    Total 15-24 unemployment (%)  1981       1982  1983       1984       1985  \
# 0                     Australia   NaN        NaN   NaN        NaN        NaN
# 1                        Canada  12.7  18.100000  19.1  17.200001  15.900000
# 2                    Czech Rep.   NaN        NaN   NaN        NaN        NaN
# 3                       Estonia   NaN        NaN   NaN        NaN        NaN
# 4                       Finland   9.2   9.800000  10.5   9.800000   9.100000
# 5                        France  17.5  18.799999  19.6  23.200001  23.200001
# 6                       Germany   NaN        NaN   NaN        NaN        NaN
# 7              Hong Kong, China   NaN        NaN   NaN        NaN   5.800000
# 8                       Ireland   NaN        NaN  20.1  22.200001  23.500000
# 9                         Japan   4.0   4.300000   4.5   4.900000   4.800000
# 10                  Korea, Rep.   NaN        NaN   NaN        NaN        NaN
# ...

# %%
cb = pd.read_excel("indicator Discount rate of central bank, per cent per annum, end of period (IMF) .xls.xlsx.")
cb
# Out:
#                       1948  1949  1950  1951  1952  1953  1954  1955  1956  \
# Albania                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Algeria                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Angola                 NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Anguilla               NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Antigua and Barbuda    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Armenia                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Aruba                  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Australia              NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Austria                  4     4     4     5     6     4     4     5     5
# Azerbaijan             NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Bahamas                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...

# %%
pu = pd.read_excel("indicator EN_URB_MCTY_TL_ZS.xls.xlsx.")
pu
# Out:
#     Population in urban agglomerations of more than 1 million (% of total population)  \
# 0                                          Afghanistan
# 1                                              Algeria
# 2                                               Angola
# 3                                            Argentina
# 4                                              Armenia
# 5                                            Australia
# 6                                              Austria
# 7                                           Azerbaijan
# 8                                           Bangladesh
# 9                                              Belarus
# 10                                             Belgium
# 11                                             Bolivia
# 12                                              Brazil
# 13                                            Bulgaria
# 14                                        Burkina Faso
# ...

# %% [markdown]
# As variáveis escolidas são a Aglomerações populares urbanas maiores que 1 milhão de pessoa e os descontos dados pelo banco centralde cada país, essas duas variáveis servião para explicar o comportamento do desemprego ao passar dos anos
#
# (imagens na pasta "Projeto 3"
